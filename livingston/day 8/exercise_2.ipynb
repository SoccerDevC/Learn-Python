# %%
import pandas as pd

series1 = pd.Series([4, 65, 436, 3, 9])
series2 = pd.Series([7, 0, 3, 897, 9])

comparison = series1 == series2
print(comparison)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
import pandas as pd

series1 = pd.Series([2, 4, 6, 8, 14])
series2 = pd.Series([1, 3, 5, 7, 9])

addition = series1 + series2
subtraction = series1 - series2
multiplication = series1 * series2
division = series1 / series2

print("Addition:")
print(addition)
print("\nSubtraction:")
print(subtraction)
print("\nMultiplication:")
print(multiplication)
print("\nDivision:")
print(division)
# Out:
# Addition:
# 0     3
# 1     7
# 2    11
# 3    15
# 4    23
# dtype: int64
#
# Subtraction:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    5
# dtype: int64
#
# Multiplication:
# 0      2
# 1     12
# 2     30
# 3     56
# 4    126
# dtype: int64
#
# Division:
# 0    2.000000
# 1    1.333333
# 2    1.200000
# 3    1.142857
# 4    1.555556
# dtype: float64

# %%
import pandas as pd

dictionary1 = {'Josh': 24, 'Sam': 36, 'Peace': 19, 'Charles': 65, 'Tom': 44}

series = pd.Series(dictionary1)
print(series)
# Out:
# Josh       24
# Sam        36
# Peace      19
# Charles    65
# Tom        44
# dtype: int64

# %%
import pandas as pd
import numpy as np

series = pd.Series(['Love', 800, 'Joy', 789.9, 'Peace', True])

array = np.array(series)
print(array)

# %%
import pandas as pd
data = pd.read_csv("AfricaCupofNationsMatches.csv")

most_frequent_value = data['HomeTeamGoals'].mode()[0]

data['HomeTeamGoals'] = data['HomeTeamGoals'].apply(lambda x: most_frequent_value if x == most_frequent_value else 'Other')
print(data['HomeTeamGoals'])
# Out:
# 0        1.0
# 1      Other
# 2      Other
# 3      Other
# 4        1.0
#        ...
# 617    Other
# 618      1.0
# 619    Other
# 620    Other
# 621    Other
# Name: HomeTeamGoals, Length: 622, dtype: object

# %%
import pandas as pd

data = pd.read_csv('AfricaCupofNationsMatches.csv')

# %%
first_seven_rows = data.head(7)
data
# Out:
#      Year                      Date   Time      HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN       Sudan           Egypt
# 1    1957                  10-Feb-57    NaN    Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN       Egypt        Ethiopia
# 3    1959                  22-May-59    NaN        Egypt       Ethiopia
# 4    1959                  25-May-59    NaN       Sudan        Ethiopia
# ..    ...                        ...    ...          ...            ...
# 617  2019  11 July 2019 (2019-07-11)  21:00  Madagascar         Tunisia
# 618  2019  14 July 2019 (2019-07-14)  18:00     Senegal         Tunisia
# 619  2019  14 July 2019 (2019-07-14)  21:00     Algeria         Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00     Tunisia         Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00     Senegal         Algeria
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# ...

# %%
selected_columns = data[['HomeTeam', 'AwayTeam', 'HomeTeamGoals', 'AwayTeamGoals']]
data
# Out:
#      Year                      Date   Time      HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN       Sudan           Egypt
# 1    1957                  10-Feb-57    NaN    Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN       Egypt        Ethiopia
# 3    1959                  22-May-59    NaN        Egypt       Ethiopia
# 4    1959                  25-May-59    NaN       Sudan        Ethiopia
# ..    ...                        ...    ...          ...            ...
# 617  2019  11 July 2019 (2019-07-11)  21:00  Madagascar         Tunisia
# 618  2019  14 July 2019 (2019-07-14)  18:00     Senegal         Tunisia
# 619  2019  14 July 2019 (2019-07-14)  21:00     Algeria         Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00     Tunisia         Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00     Senegal         Algeria
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# ...

# %%
egypt_rows = data[data['HomeTeam'] == 'Egypt']
data

# %%
num_rows, num_columns = data.shape

# %%
missing_attendance_rows = data[data['Attendance'].isnull()]

# %%
selected_rows = data[(data['HomeTeamGoals'] >= 3) & (data['HomeTeamGoals'] <= 6)]

# %%
data.at[2, 'AwayTeamGoals'] = 10

# %%
sorted_data = data.sort_values(by=['HomeTeam', 'HomeTeamScores'], ascending=[True, False])

# %%
column_headers = list(data.columns)

# %%
data['Countries_left_out'] = ["Uganda", "Rwanda", "Kenya","Zimbabwe"]

# %%
new_rows = pd.DataFrame([[value1, value2, value3, ...], [value4, value5, value6, ...]], columns=data.columns)
data = data.append(new_rows, ignore_index=True)

# %%
data.loc[data['AwayTeam'] == 'Uganda', 'AwayTeam'] = 'China'

# %%
data.reset_index(drop=True, inplace=True)

# %%
if 'Stadium' in data.columns:
    print("The 'Stadium' column is present.")
else:
    print("The 'Stadium' column is not present.")

# %%
data['AwayTeamGoals'] = data['AwayTeamGoals'].astype(float)

# %%
data = data[:-10]

# %%
for index, row in data.iterrows():
    # Access row data using row[column_name]
    # Example: print(row['HomeTeam'], row['AwayTeam'])
    pass  # Replace 'pass' with your code logic
