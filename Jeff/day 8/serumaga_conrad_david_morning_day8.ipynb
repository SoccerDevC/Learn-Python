# %%
import pandas as pd

# %%
df4 = pd.read_csv("bse_dataset4.csv")
df4
# Out:
#                Timestamp         gender   Age  emotion   YOB     CGPA  \
# 0    05/07/2023 09:38:39           Male  21.0  Content  2002     4.22
# 1    05/07/2023 09:38:57  Marabou stock  45.0    Weird  2100      8.9
# 2    05/07/2023 09:39:09        Female   20.0    Happy  2002     3.98
# 3    05/07/2023 09:39:12           Male  21.0    Happy  2003     4.37
# 4    05/07/2023 09:39:14         Female  21.0    Happy  2002     3.63
# ..                   ...            ...   ...      ...   ...      ...
# 164  05/07/2023 09:44:09           Male  22.0   Angry   1999      3.5
# 165  05/07/2023 09:44:14           male  23.0      sad  1999        4
# 166  05/07/2023 09:44:15           male  20.0     calm  2002      3.7
# 167  05/07/2023 09:44:35         Female  21.0      sad  2001      3.8
# 168  05/07/2023 09:45:13         Female  20.0    Happy  2022  4......
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# ...

# %%
#Exercise 1
#Calculate mode on age

# %%
print(mode_age)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 print(mode_age)
#
# NameError: name 'mode_age' is not defined

# %%
#wrong formats Row is hard to analyze (NaN, )
#NaN Row 5 contained NaN values

df4["Timestamp"].fillna("05/07/2023 09:45:13", inplace=True)

df4
# Out:
#                Timestamp         gender   Age  emotion   YOB     CGPA  \
# 0    05/07/2023 09:38:39           Male  21.0  Content  2002     4.22
# 1    05/07/2023 09:38:57  Marabou stock  45.0    Weird  2100      8.9
# 2    05/07/2023 09:39:09        Female   20.0    Happy  2002     3.98
# 3    05/07/2023 09:39:12           Male  21.0    Happy  2003     4.37
# 4    05/07/2023 09:39:14         Female  21.0    Happy  2002     3.63
# ..                   ...            ...   ...      ...   ...      ...
# 164  05/07/2023 09:44:09           Male  22.0   Angry   1999      3.5
# 165  05/07/2023 09:44:14           male  23.0      sad  1999        4
# 166  05/07/2023 09:44:15           male  20.0     calm  2002      3.7
# 167  05/07/2023 09:44:35         Female  21.0      sad  2001      3.8
# 168  05/07/2023 09:45:13         Female  20.0    Happy  2022  4......
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# ...

# %%
import pandas as pd
crime_csv=pd.read_csv("2018CrimeStatisticsByCategoryOfCrime.csv")
crime_csv.head(10)
# Out:
#   Unnamed: 0                            Unnamed: 1 REPORTED CASES  \
# 0        NaN                                   NaN            NaN
# 1        NaN                                   NaN   Totals Cases
# 2      S/No.                 CASE/CRIME INCIDENCES              1
# 3        NaN                             HOMICIDES            NaN
# 4          1                  Death  (by shooting)            190
# 5          2                 Death (by mob action)            636
# 6          3                     Death (Poisoning)             81
# 7          4  Death (Aggravated Domestic Violence)            362
# 8          5                Death(Fire Out Breaks)             42
# 9          8     Other Death (Not Specified above)          3,186
#
#             Unnamed: 3        Unnamed: 4            Unnamed: 5  \
# 0                  NaN               NaN                   NaN
# 1  Cases under Inquiry  Not Detected/NPW  Cases taken to court
# ...

# %%
crime_csv.dropna(axis = 0, inplace=True )
crime_csv.head(10)
# Out:
#    Unnamed: 0                            Unnamed: 1 REPORTED CASES Unnamed: 3  \
# 4           1                  Death  (by shooting)            190        117
# 5           2                 Death (by mob action)            636        431
# 6           3                     Death (Poisoning)             81         54
# 7           4  Death (Aggravated Domestic Violence)            362        107
# 8           5                Death(Fire Out Breaks)             42         25
# 9           8     Other Death (Not Specified above)          3,186      1,740
# 12          9                          Embezzlement            199        172
# 13         10               Causing Financial losss             58         49
# 14         11                       Abuse of office             50         39
# 15         12                        Counterfeiting            541        215
#
#    Unnamed: 4 Unnamed: 5 PERFOMANCE Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# ...

# %%
crime_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 83 entries, 4 to 124
# Data columns (total 38 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   83 non-null     object
#  1   Unnamed: 1                   83 non-null     object
#  2   REPORTED CASES               83 non-null     object
#  3   Unnamed: 3                   83 non-null     object
#  4   Unnamed: 4                   83 non-null     object
#  5   Unnamed: 5                   83 non-null     object
#  6   PERFOMANCE                   83 non-null     object
#  7   Unnamed: 7                   83 non-null     object
#  8   Unnamed: 8                   83 non-null     object
#  9   Unnamed: 9                   83 non-null     object
#  10  Unnamed: 10                  83 non-null     object
#  11  PERSONS TAKEN TO COURT       83 non-null     object
#  12  Unnamed: 12                  83 non-null     object
# ...

# %%
crime_csv.astype(int)
crime_csv.info()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 crime_csv.astype(int)
#       2 crime_csv.info()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# ...

# %%
#Statistics for Data Science
#Descriptive Statistics, measure central Tendency(Mean, median, mode) Measure dispersion (standard)
#Probability
#Inferential Statistics(make predictions, identify, variables and hypothesis)
#Modeling
#ML
#regression, classification, cluster, anomaly detection

#+256722359866

#python data correlation
#use method corr( calculates correlation coefficients between all columns in dataframe)
#Strong positive correlation 1 Strong Negative correlation -1
#Good correlation 0.93455 Good correlation above 0.5
#Bad correlation when is less than 0.5 
#Perfect correlation 1 Perfect Negative correlation 1
#

# %%
import matplotlib.pyplot as plt

# %%
uneb = pd.read_csv('UceResultsBySchool2011-2016.csv')
uneb.describe()
# Out:
#                YEAR  TOTAL CANDIDATES   TOTAL DIV 1       % DIV 1  \
# count  17639.000000      17368.000000  12858.000000  17639.000000
# mean    2013.582119        100.111469     10.348266      6.226481
# std        1.710821         66.964610     26.214334     13.266156
# min     2011.000000          1.000000      0.000000      0.000000
# 25%     2012.000000         54.000000      1.000000      0.000000
# 50%     2014.000000         84.000000      3.000000      1.800000
# 75%     2015.000000        128.000000      8.000000      5.700000
# max     2016.000000        499.000000    430.000000    100.000000
#
#         TOTAL DIV 2       % DIV 2   TOTAL DIV 3       % DIV 3   TOTAL DIV 4  \
# count  16880.000000  17639.000000  17168.000000  17639.000000  16888.000000
# mean      16.058649     14.748733     22.545841     22.165344     45.981348
# std       19.324105     12.800108     17.804404     10.241613     35.558741
# ...

# %%
uneb.count(0)
# Out:
# YEAR                  17639
# DISTRICT              17639
# SCHOOL                17638
# TOTAL CANDIDATES      17368
# TOTAL DIV 1           12858
# % DIV 1               17639
# TOTAL DIV 2           16880
# % DIV 2               17639
# TOTAL DIV 3           17168
# % DIV 3               17639
# TOTAL DIV 4           16888
# % DIV 4               17639
# TOTAL DIV 7            6489
# % DIV 7               17639
# TOTAL DIV 9           13454
# % DIV 9               17639
# TOTAL X               13404
# % X                   17639
# FEMALE CANDIDATES     17639
# FEMALE TOTAL DIV1      8525
# FEMALE % DIV1         17581
# FEMALE TOTAL DIV2     14332
# FEMALE % DIV2         17581
# FEMALE TOTAL DIV3     16474
# FEMALE % DIV3         17581
# FEMALE TOTAL DIV4     16681
# FEMALE % DIV4         17581
# FEMALE TOTAL DIV7      4764
# FEMALE % DIV7         17581
# FEMALE TOTAL DIV9     12349
# FEMALE % DIV9         17581
# FEMALE TOTAL X        10596
# FEMALE % X            17581
# ...

# %%
uneb.count(1)
# Out:
# 0        31
# 1        30
# 2        31
# 3        32
# 4        31
#          ..
# 17634    48
# 17635    48
# 17636    48
# 17637    48
# 17638    48
# Length: 17639, dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0,6 ])
ypoints = np.array([0,560])

plt.plot(xpoints, ypoints)
plt.show()
